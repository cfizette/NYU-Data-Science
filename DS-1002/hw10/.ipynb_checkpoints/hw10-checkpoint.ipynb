# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
matplotlib.rcParams['figure.figsize'] = [15, 8]
# Out:
# /home/cfizette/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # 6b

# %% [markdown]
# ### Posterior distribution
# $$\pi (\theta|x)\propto \exp(-\frac{n}{2}(\theta - \bar{X}_{n})^2)\cdot \frac{1}{\theta^2+1}$$

# %%
samp = [-1.249, 3.134, 0.825, 0.036, 0.814, -0.105]
n = len(samp)

# %%
x_bar = np.mean(samp)

# %%
thetas = np.linspace(-3,3,100)

# %%
pdf = np.exp(-(n/2)*(thetas - x_bar)**2)*(1/(np.power(thetas,2) + 1))

# %%
plt.plot(thetas, pdf)
plt.title('PDF of Posterior Distribution')
plt.xlabel('Theta')
plt.ylabel('P(theta|x)')
# Out:
# Text(0,0.5,'P(theta|x)')

# %%
def f(x):
    return np.exp(-(n/2)*(x - x_bar)**2)*(1/(np.power(x,2) + 1))

# %%
def q(x, mu):
    return np.exp(-3*(x-mu)**2)

# %%
def rho(x,y):
    ratio = (f(y)*q(x,y))/(f(x)*q(y,x))
    return min(ratio, 1)

# %%
sigma=1/6

# %%
X = [0]
for i in range(6000):
    y = np.random.normal(X[i], sigma)
    rho_ = rho(X[i],y)
    X_new = float(np.random.choice([y,X[i]],1, p=[rho_, 1-rho_]))
    X.append(X_new)
X = np.array(X[1000:])

# %%
plt.hist(X, normed=True, bins=20, label='Histogram of Samples')
plt.plot(thetas, pdf, label='True PDF')
plt.title('Distribution of Samples from Metropolis-Hasings Algorithm')
plt.xlabel('Theta')
plt.ylabel('P(theta|x)')
plt.legend(loc='best')

# %% [markdown]
# # 6c

# %%
e_x = np.mean(X)

# %%
p_0_1 = len(X[(0 < X) & (X < 1)])/len(X)

# %%
print("E(theta|x) = {}".format(e_x))
# Out:
# E(theta|x) = 0.46470057589611125

# %%
print("P(0 < theta < 1 | x) = {}".format(p_0_1))
# Out:
# P(0 < theta < 1 | x) = 0.8112377524495101
