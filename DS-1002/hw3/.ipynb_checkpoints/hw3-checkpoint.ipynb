# %%
import numpy as np
from math import log as ln
import matplotlib.pyplot as plt
from numpy.random import rand as unif
from scipy.stats import poisson, gamma

# %%
plt.rcParams['figure.figsize'] = [15, 10]

# %%
def gen_poisson(lam):
    u = unif()
    i=0
    while True:
        F1 = poisson.cdf(k=i-1,mu=lam)
        F2 = poisson.cdf(k=i, mu=lam)
        if F1 <= u <= F2:
            return i
        i += 1

# %%
poisson_samp = []
for i in range(10000):
    poisson_samp.append(gen_poisson(2))

# %%
plt.hist(poisson_samp)
# Out:
# (array([1.350e+03, 2.729e+03, 2.667e+03, 1.802e+03, 9.170e+02, 3.660e+02,
#         1.190e+02, 4.100e+01, 7.000e+00, 2.000e+00]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <a list of 10 Patch objects>)

# %%
def gen_expon(b):
    u = unif()
    return -ln(1-u)*b

# %%
def gen_gamma(a, b):
    u = unif() 
    # Generate n=a Expon(b) random variables and sum them up
    expon_sample = [gen_expon(b) for i in range(a)]
    return sum(expon_sample)

# %%
gamma_sample = [gen_gamma(5,0.5) for i in range(1000)]

# %%
# gamma.rvs does not take in a scale parameter, have to multiply
true_gamma_sample = [0.5*gamma.rvs(5) for i in range(1000)]

# %%
plt.hist(gamma_sample)
plt.hist(true_gamma_sample)
# Out:
# (array([ 53., 242., 294., 224., 110.,  40.,  23.,   7.,   5.,   2.]),
#  array([0.27171384, 1.05970614, 1.84769843, 2.63569072, 3.42368301,
#         4.2116753 , 4.9996676 , 5.78765989, 6.57565218, 7.36364447,
#         8.15163677]),
#  <a list of 10 Patch objects>)
